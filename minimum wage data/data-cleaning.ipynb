# %%
import pandas as pd

# %%
# median household income by state to df
med_income_df = pd.read_excel('Median Household Income by State 1984 to 2020.xlsx')
med_income_df
# Out:
#    Table with row headers in column A and column headers in rows 8 through 9 and 63 through 64  \
# 0                                               State
# 1                                       United States
# 2                                             Alabama
# 3                                              Alaska
# 4                                             Arizona
# 5                                            Arkansas
# 6                                          California
# 7                                            Colorado
# 8                                         Connecticut
# 9                                            Delaware
# 10                               District of Columbia
# 11                                            Florida
# 12                                            Georgia
# 13                                             Hawaii
# 14                                              Idaho
# 15                                           Illinois
# ...
